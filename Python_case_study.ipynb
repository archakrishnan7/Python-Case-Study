# %% [markdown]
# <a href="https://colab.research.google.com/github/archakrishnan7/Python-Case-Study/blob/main/Python_case_study.ipynb" target="_parent"><img src="https://colab.research.google.com/assets/colab-badge.svg" alt="Open In Colab"/></a>

# %% [markdown]
# 1. Bank Account Manager
#
# a. Simulate a bank account with deposit, withdrawal, and balance
# enquiry operations
#
# b. Use variables and data types to store account information
#
# c. Implement conditional statements to check for sufficient balance
# before withdrawal
#
# d. Use functions to perform deposit, withdrawal, and balance inquiry
# operations.

# %%
class BankAccountManager:
  def __init__ (self,owner,acc_no,balance):
     self.owner = owner
     self.acc_no = acc_no
     self.balance = balance

  def deposite(self,amount):
    if amount>=0:
      self.balance += amount
      print(f"Deposited {amount:.2f} Balance: {self.balance: 2f}")
    else:
      print("Invalid Action")
  def withdraw(self,amount):
    if amount>=0:
      if self.balance>=amount:
       self.balance-=amount
       print(f"Withdraw {amount:.2f} Balance: {self.balance:2f}")
      else:
        print("Insufficient Balance")
    else:
      print("Invalid Action")
  def display(self):
    print(f"owner:{self.owner} acc_no:{self.acc_no:2f} balance:{self.balance:2f}")

customer1=BankAccountManager("Archa",197770,10000)
customer1.display()
customer1.withdraw(5000)
customer1.display()
customer1.deposite(1000)
customer1.display()
customer1.withdraw(7500)
customer1.display()
# Out:
# owner:Archa acc_no:197770.000000 balance:10000.000000
# Withdraw 5000.00 Balance: 5000.000000
# owner:Archa acc_no:197770.000000 balance:5000.000000
# Deposited 1000.00 Balance:  6000.000000
# owner:Archa acc_no:197770.000000 balance:6000.000000
# Insufficient Balance
# owner:Archa acc_no:197770.000000 balance:6000.000000

# %% [markdown]
# 2. Weather Data Analyzer
#
# a. Analyze weather data (temperature, humidity, etc.) for a given region
#
# b. Use variables and data types to store weather data
# (sunny, rainy, etc.)
# results
#
# c. Implement conditional statements to determine weather conditions
#
# d. Use functions to calculate average temperature and humidity, and print

# %%
class WeatherDataAnalyzer:
  def __init__(self,temperature,humidity):
    self.temperature = temperature
    self.humidity  = humidity
  def Weather(self):
    average = (self.temperature+self.humidity)/2
    if average>25:
      print("The weather is hot")
    elif average<=20:
      print("The weather is cold and rainy")
    else:
      print("Weather is very cold")
weather=WeatherDataAnalyzer(42,10)
weather.Weather()
# Out:
# The weather is hot
